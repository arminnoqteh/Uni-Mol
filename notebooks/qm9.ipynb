# %%
import unimol_tools
# Out:
# 2024-12-18 12:50:32 | unimol_tools/weights/weighthub.py | 17 | INFO | Uni-Mol Tools | Weights will be downloaded to default directory: /opt/anaconda3/envs/MPP/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/weights

# %%
import os
import urllib.request

URL = "https://deepchemdata.s3-us-west-1.amazonaws.com/datasets/qm9.csv"
filename = os.path.basename(URL)
if not os.path.isfile(filename):
    urllib.request.urlretrieve(URL, filename)
train_data = filename

# %%
from unimol_tools import MolTrain, MolPredict
import pandas as pd

clf = MolTrain(task='regression', 
                data_type='molecule', 
                epochs=10, 
                batch_size=16, 
                metrics='mae',
                model_name='unimolv2',
                model_size='84m',
                split= "group",
                smiles_col="smiles",
                target_cols=['homo','lumo','gap']
                )

pred = clf.fit(data = train_data)
# Out:
# 2024-12-18 12:20:39 | unimol_tools/data/datareader.py | 192 | INFO | Uni-Mol Tools | Anomaly clean with 3 sigma threshold: 133885 -> 132311
# 2024-12-18 12:20:52 | unimol_tools/data/conformer.py | 310 | INFO | Uni-Mol Tools | Start generating conformers...
# 0it [00:00, ?it/s]2024-12-18 12:20:56 | unimol_tools/weights/weighthub.py | 17 | INFO | Uni-Mol Tools | Weights will be downloaded to default directory: /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/weights
# 2024-12-18 12:20:56 | unimol_tools/weights/weighthub.py | 17 | INFO | Uni-Mol Tools | Weights will be downloaded to default directory: /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/weights
# 2024-12-18 12:20:56 | unimol_tools/weights/weighthub.py | 17 | INFO | Uni-Mol Tools | Weights will be downloaded to default directory: /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/weights
# 2024-12-18 12:20:56 | unimol_tools/weights/weighthub.py | 17 | INFO | Uni-Mol Tools | Weights will be downloaded to default directory: /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/weights
# 2024-12-18 12:20:56 | unimol_tools/weights/weighthub.py | 17 | INFO | Uni-Mol Tools | Weights will be downloaded to default directory: /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/weights
# 2024-12-18 12:20:56 | unimol_tools/weights/weighthub.py | 17 | INFO | Uni-Mol Tools | Weights will be downloaded to default directory: /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/weights
# 2024-12-18 12:20:56 | unimol_tools/weights/weighthub.py | 17 | INFO | Uni-Mol Tools | Weights will be downloaded to default directory: /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/weights
# 2024-12-18 12:20:56 | unimol_tools/weights/weighthub.py | 17 | INFO | Uni-Mol Tools | Weights will be downloaded to default directory: /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/weights
# 2024-12-18 12:20:56 | unimol_tools/weights/weighthub.py | 17 | INFO | Uni-Mol Tools | Weights will be downloaded to default directory: /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/weights
# 2024-12-18 12:20:56 | unimol_tools/weights/weighthub.py | 17 | INFO | Uni-Mol Tools | Weights will be downloaded to default directory: /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/weights
# 17634it [00:26, 677.57it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /opt/anaconda3/envs/uni_mol/lib/python3.12/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 17
#       4 clf = MolTrain(task='regression',
#       5                 data_type='molecule',
#       6                 epochs=10,
#    (...)
#      13                 target_cols=['homo','lumo','gap']
#      14                 )
#      16 train_data = "../../../../Downloads/qm9.csv"
# ---> 17 pred = clf.fit(data = train_data)
#
# File /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/train.py:152, in MolTrain.fit(self, data)
#     134 def fit(self, data):
#     135     """
#     136     Fit the model according to the given training data with multi datasource support, including SMILES csv file and custom coordinate data.
#     137
#    (...)
#     150         clf.fit(custom_data)
#     151     """
# --> 152     self.datahub = DataHub(data = data, is_train=True, save_path=self.save_path, **self.config)
#     153     self.data = self.datahub.data
#     154     self.update_and_save_config()
#
# File /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/data/datahub.py:33, in DataHub.__init__(self, data, is_train, save_path, **params)
#      31 self.multiclass_cnt = params.get('multiclass_cnt', None)
#      32 self.ss_method = params.get('target_normalize', 'none')
# ---> 33 self._init_data(**params)
#
# File /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/data/datahub.py:89, in DataHub._init_data(self, **params)
#      87     else:
#      88         smiles_list = self.data["smiles"]
# ---> 89         no_h_list = UniMolV2Feature().transform(smiles_list)
#      91 self.data['unimol_input'] = no_h_list
#
# File /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/unimol_tools-0.1.1.post1-py3.12.egg/unimol_tools/data/conformer.py:311, in UniMolV2Feature.transform(self, smiles_list)
#     309 pool = Pool()
#     310 logger.info('Start generating conformers...')
# --> 311 inputs = [item for item in tqdm(pool.imap(self.single_process, smiles_list))]
#     312 pool.close()
#     313 # failed_cnt = np.mean([(item['src_coord']==0.0).all() for item in inputs])
#     314 # logger.info('Succeeded in generating conformers for {:.2f}% of molecules.'.format((1-failed_cnt)*100))
#     315 # failed_3d_cnt = np.mean([(item['src_coord'][:,2]==0.0).all() for item in inputs])
#     316 # logger.info('Succeeded in generating 3d conformers for {:.2f}% of molecules.'.format((1-failed_3d_cnt)*100))
#
# File /opt/anaconda3/envs/uni_mol/lib/python3.12/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File /opt/anaconda3/envs/uni_mol/lib/python3.12/multiprocessing/pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File /opt/anaconda3/envs/uni_mol/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:
